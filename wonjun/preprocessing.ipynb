# %%
# !pwd
# Out:
# /opt/ml/level1_bookratingprediction_recsys-level1-recsys-02/wonjun

# %%
#!pip install seaborn
# Out:
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.8/site-packages (0.12.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.8/site-packages (from seaborn) (1.23.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /opt/conda/lib/python3.8/site-packages (from seaborn) (3.6.0)
# Requirement already satisfied: pandas>=0.25 in /opt/conda/lib/python3.8/site-packages (from seaborn) (1.5.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (8.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/ml/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/ml/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/ml/.local/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.8/site-packages (from pandas>=0.25->seaborn) (2020.5)
# Requirement already satisfied: six>=1.5 in /opt/ml/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as ss
# from autocorrect import Speller
# import nltk
# nltk.download('punkt') => 이거까진 필요없어

# %%
users_origin = pd.read_csv('../main_code/data/users.csv')
books_origin = pd.read_csv("../main_code/data/books.csv", encoding='utf-8')
ratings_origin = pd.read_csv('../main_code/data/train_ratings.csv')
test_origin = pd.read_csv('../main_code/data/test_ratings.csv')

# %%
users = pd.read_csv('../main_code/data/users.csv')
books = pd.read_csv("../main_code/data/books.csv", encoding='utf-8')
ratings = pd.read_csv('../main_code/data/train_ratings.csv')
test = pd.read_csv('../main_code/data/test_ratings.csv')

# %%
def text_preprocessing_func(text : str ) -> str :
    """
    깨진 문자를 변환하는 함수
    """
    text = text.replace('Ã?Â©','e') # 원래는 é인데 걍 e로 메움
    text = text.replace('Ã©', 'e')
    text = text.replace('Ã?Â?','e') # 원래는 é인데 걍 e로 메움
    text = text.lower()
    return text

# %%
users
# Out:
#        user_id                            location   age
# 0            8            timmins, ontario, canada   NaN
# 1        11400             ottawa, ontario, canada  49.0
# 2        11676                       n/a, n/a, n/a   NaN
# 3        67544            toronto, ontario, canada  30.0
# 4        85526  victoria, british columbia, canada  36.0
# ...        ...                                 ...   ...
# 68087   278376         danville, pennsylvania, usa  54.0
# 68088   278621          victoria, delaware, canada  74.0
# 68089   278636             irvington, alabama, usa   NaN
# 68090   278659          vancouver, washington, usa  33.0
# 68091   278713        albuquerque, new mexico, usa  63.0
#
# [68092 rows x 3 columns]

# %% [markdown]
# # USERS
# - AGE column은 삭제합니다

# %%
users['user_id'].nunique()
# Out:
# 68092

# %% [markdown]
# #### AGE COLUMN 삭제

# %%
users.isna().sum()
# Out:
# user_id         0
# location        0
# age         27833
# dtype: int64

# %%
users = users.drop('age', axis=1)

# %%
users
# Out:
#        user_id                            location
# 0            8            timmins, ontario, canada
# 1        11400             ottawa, ontario, canada
# 2        11676                       n/a, n/a, n/a
# 3        67544            toronto, ontario, canada
# 4        85526  victoria, british columbia, canada
# ...        ...                                 ...
# 68087   278376         danville, pennsylvania, usa
# 68088   278621          victoria, delaware, canada
# 68089   278636             irvington, alabama, usa
# 68090   278659          vancouver, washington, usa
# 68091   278713        albuquerque, new mexico, usa
#
# [68092 rows x 2 columns]

# %% [markdown]
# ## LOCATION
# - location state, city, country 가 na인 row들 날려줌
# - location country 이상한 애들 직접 확인해서 수정
# - location, location city column 삭제
# - location state는 원하는대로 결정하기

# %%
# USERS에서 location을 location country, city, state로 나눠줌

users['location'] = users['location'].str.replace(r'[^0-9a-zA-Z:,]', '') # 특수문자 제거

users['location_city'] = users['location'].apply(lambda x: x.split(',')[0].strip())
users['location_state'] = users['location'].apply(lambda x: x.split(',')[1].strip())
users['location_country'] = users['location'].apply(lambda x: x.split(',')[2].strip())

users = users.replace('na', np.nan) #특수문자 제거로 n/a가 na로 바뀌게 되었습니다. 따라서 이를 컴퓨터가 인식할 수 있는 결측값으로 변환합니다.
users = users.replace('', np.nan) # 일부 경우 , , ,으로 입력된 경우가 있었으므로 이런 경우에도 결측값으로 변환합니다.

modify_location = users[(users['location_country'].isna())&(users['location_city'].notnull())]['location_city'].values
location = users[(users['location'].str.contains('seattle'))&(users['location_country'].notnull())]['location'].value_counts().index[0]

location_list = []
for location in modify_location:
    try:
        right_location = users[(users['location'].str.contains(location))&(users['location_country'].notnull())]['location'].value_counts().index[0]
        location_list.append(right_location)
    except:
        pass
    
for location in location_list:
    users.loc[users[users['location_city']==location.split(',')[0]].index,'location_state'] = location.split(',')[1]
    users.loc[users[users['location_city']==location.split(',')[0]].index,'location_country'] = location.split(',')[2]
# Out:
# /tmp/ipykernel_22297/1343807041.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   users['location'] = users['location'].str.replace(r'[^0-9a-zA-Z:,]', '') # 특수문자 제거

# %%
users.isna().sum()
# Out:
# user_id                0
# location               0
# location_city        122
# location_state      1132
# location_country     271
# dtype: int64

# %%
users
# Out:
#        user_id                         location location_city  \
# 0            8           timmins,ontario,canada       timmins
# 1        11400            ottawa,ontario,canada        ottawa
# 2        11676                         na,na,na           NaN
# 3        67544           toronto,ontario,canada       toronto
# 4        85526  victoria,britishcolumbia,canada      victoria
# ...        ...                              ...           ...
# 68087   278376        danville,pennsylvania,usa      danville
# 68088   278621         victoria,delaware,canada      victoria
# 68089   278636            irvington,alabama,usa     irvington
# 68090   278659         vancouver,washington,usa     vancouver
# 68091   278713        albuquerque,newmexico,usa   albuquerque
#
#         location_state location_country
# 0              ontario           canada
# 1              ontario           canada
# 2                  NaN              NaN
# 3              ontario           canada
# 4      britishcolumbia           canada
# ...                ...              ...
# 68087       california              usa
# 68088         delaware           canada
# 68089          alabama              usa
# 68090  britishcolumbia           canada
# 68091        newmexico              usa
#
# [68092 rows x 5 columns]

# %% [markdown]
# #### location state, city, country가 na인 애들 날려줌 (왜냐! 몇개없음)

# %%
users = users.dropna(subset=['location_state', 'location_city', 'location_country']).reset_index(drop=True)

# %%
users
# Out:
#        user_id                         location location_city  \
# 0            8           timmins,ontario,canada       timmins
# 1        11400            ottawa,ontario,canada        ottawa
# 2        67544           toronto,ontario,canada       toronto
# 3        85526  victoria,britishcolumbia,canada      victoria
# 4        96054            ottawa,ontario,canada        ottawa
# ...        ...                              ...           ...
# 66798   278376        danville,pennsylvania,usa      danville
# 66799   278621         victoria,delaware,canada      victoria
# 66800   278636            irvington,alabama,usa     irvington
# 66801   278659         vancouver,washington,usa     vancouver
# 66802   278713        albuquerque,newmexico,usa   albuquerque
#
#         location_state location_country
# 0              ontario           canada
# 1              ontario           canada
# 2              ontario           canada
# 3      britishcolumbia           canada
# 4              ontario           canada
# ...                ...              ...
# 66798       california              usa
# 66799         delaware           canada
# 66800          alabama              usa
# 66801  britishcolumbia           canada
# 66802        newmexico              usa
#
# [66803 rows x 5 columns]

# %% [markdown]
# #### locationcolumn도 날려줌 (분리했으니까)

# %%
users = users.drop('location', axis=1)

# %%
users
# Out:
#        user_id location_city   location_state location_country
# 0            8       timmins          ontario           canada
# 1        11400        ottawa          ontario           canada
# 2        67544       toronto          ontario           canada
# 3        85526      victoria  britishcolumbia           canada
# 4        96054        ottawa          ontario           canada
# ...        ...           ...              ...              ...
# 66798   278376      danville       california              usa
# 66799   278621      victoria         delaware           canada
# 66800   278636     irvington          alabama              usa
# 66801   278659     vancouver  britishcolumbia           canada
# 66802   278713   albuquerque        newmexico              usa
#
# [66803 rows x 4 columns]

# %% [markdown]
# ### location country에서 이상한 애들 확인

# %%
min(users['location_country'].apply(len))
# Out:
# 1

# %% [markdown]
# #### location_country가 이상한 애들은 직접 수정해드렸습니다^^

# %%
users[users['location_country'].apply(len)==1]
# Out:
#        user_id location_city location_state location_country
# 44506    41195             c              c                c

# %%
# 너무 더러운데.. 어쩌지
users[users['location_country']=='']
# Out:
# Empty DataFrame
# Columns: [user_id, location_city, location_state, location_country]
# Index: []

# %%
country_fix_dict = {'usa': {'oklahoma','districtofcolumbia', 'connecticut', 'worcester', 'aroostook', 'texas',  'kern', 'orangeco', 'unitedstatesofamerica', 'fortbend', 'alachua', 'massachusetts', 'arizona', 'austin', 'hawaii', 'ohio', 'camden', 'arkansas', 'minnesota', 'losestadosunidosdenorteamerica', 'us', 'usanow', 'northcarolina', 'maine', 'colorado','oklahoma', 'alabama', 'anystate', 'districtofcolumbia', 'unitedstaes', 'pender', 'newhampshire', 'unitedstates', 'missouri', 'idaho', 'ca', 'newyork','tennessee', 'stthomasi', 'dc', 'washington', 'illinois', 'california', 'michigan', 'iowa', 'maryland', 'newjersey', 'vanwert', 'oregon'},
                    'uk': {'alderney', 'wales',  'aberdeenshire', 'bermuda', 'nottinghamshire', 'scotland', 'usacurrentlylivinginengland', 'england', 'countycork', 'alderney', 'cambridgeshire', 'middlesex', 'northyorkshire', 'westyorkshire', 'cocarlow', 'sthelena'},
                    'japan': {'okinawa'},
                    'southkorea': {'seoul'},
                    'canada': {'ontario', 'alberta', 'novascotia', 'newfoundland', 'newbrunswick', 'britishcolumbia'},
                    'miyanma': {'burma'},
                    'newzealand': {'auckland', 'nz', 'otago'},
                    'spain': {'andalucia','pontevedra', 'gipuzkoa', 'lleida', 'catalunyaspain', 'galiza', 'espaa'},
                    'germany': {'niedersachsen', 'deutschland'},
                    'brazil': {'disritofederal'},
                    'switzerland': {'lasuisse'},
                    'italy': {'veneziagiulia', 'ferrara', 'italia'},
                    'australia': {'nsw', 'queensland', 'newsouthwales'},
                    'belgium': {'labelgique', 'bergued'},
                    'uruguay': {'urugua'},
                    'panama': {'republicofpanama'}
                   }
country_del_list = ['c', 'space', 'universe', 'unknown', 'quit', 'tdzimi', 'universe', 'tn', 'unknown', 'space', 'c', 'franciscomorazan', 'petrolwarnation', 'ineurope', 'hereandthere', 'faraway']

# %%
users
# Out:
#        user_id location_city   location_state location_country
# 0            8       timmins          ontario           canada
# 1        11400        ottawa          ontario           canada
# 2        67544       toronto          ontario           canada
# 3        85526      victoria  britishcolumbia           canada
# 4        96054        ottawa          ontario           canada
# ...        ...           ...              ...              ...
# 66798   278376      danville       california              usa
# 66799   278621      victoria         delaware           canada
# 66800   278636     irvington          alabama              usa
# 66801   278659     vancouver  britishcolumbia           canada
# 66802   278713   albuquerque        newmexico              usa
#
# [66803 rows x 4 columns]

# %%
del_idx = []
for idx, row in enumerate(users['location_country']):
    for key, value in country_fix_dict.items():
        if row in value:
            users.at[idx, 'location_country'] = key
    if row in country_del_list:
        del_idx.append(idx)

# %%
users = users.drop(del_idx, axis=0).reset_index(drop=True)

# %%
users
# Out:
#        user_id location_city   location_state location_country
# 0            8       timmins          ontario           canada
# 1        11400        ottawa          ontario           canada
# 2        67544       toronto          ontario           canada
# 3        85526      victoria  britishcolumbia           canada
# 4        96054        ottawa          ontario           canada
# ...        ...           ...              ...              ...
# 66785   278376      danville       california              usa
# 66786   278621      victoria         delaware           canada
# 66787   278636     irvington          alabama              usa
# 66788   278659     vancouver  britishcolumbia           canada
# 66789   278713   albuquerque        newmexico              usa
#
# [66790 rows x 4 columns]

# %% [markdown]
# #### location_state 맛만 보겠습니다

# %%
users['location_state'].value_counts()
# Out:
# california         6873
# ontario            2504
# texas              2504
# newyork            2398
# england            2230
#                    ...
# grancanaria           1
# vallsoccidental       1
# soria                 1
# galway                1
# ccp                   1
# Name: location_state, Length: 1298, dtype: int64

# %% [markdown]
# #### location_city 날립니다
# - location_state를 날리고 싶다면 알아서 하세요

# %%
# 날릴까 말까 => state를 날리고 싶다면 주석 푸세요
# users = users.drop('location_state', axis=1)
users = users.drop('location_city', axis=1)

# %%
users
# Out:
#        user_id   location_state location_country
# 0            8          ontario           canada
# 1        11400          ontario           canada
# 2        67544          ontario           canada
# 3        85526  britishcolumbia           canada
# 4        96054          ontario           canada
# ...        ...              ...              ...
# 66785   278376       california              usa
# 66786   278621         delaware           canada
# 66787   278636          alabama              usa
# 66788   278659  britishcolumbia           canada
# 66789   278713        newmexico              usa
#
# [66790 rows x 3 columns]

# %% [markdown]
# # BOOKS
# - summary : 날리자! 사유는 언어가 다 다른데 이거 모델에 넣고 돌리기 too much 노동 크롤링 하면 안 되니까 할 수 없다..가 의견입니다.
# - year_of_publication : float -> int
# - category : 보류
# - language : isbn 코드로 채워주자
#   https://en.wikipedia.org/wiki/List_of_ISBN_registration_groups

# %%
books = pd.read_csv("../main_code/data/books.csv", encoding='utf-8')

# %%
# float이라서 int로 바꿔줌
books['year_of_publication'] = books['year_of_publication'].astype(int)

# %% [markdown]
# ## Summary 삭제

# %%
books = books.drop('summary', axis=1) ; books
# Out:
#               isbn                                         book_title  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0399135782                             The Kitchen God's Wife
# 4       0425176428  What If?: The World's Foremost Military Histor...
# ...            ...                                                ...
# 149565  067161746X  The Bachelor Home Companion: A Practical Guide...
# 149566  0767907566  All Elevations Unknown: An Adventure in the He...
# 149567  0884159221  Why stop?: A guide to Texas historical roadsid...
# 149568  0912333022  The Are You Being Served? Stories: 'Camping In...
# 149569  1569661057  Dallas Street Map Guide and Directory, 2000 Ed...
#
#                  book_author  year_of_publication                 publisher  \
# 0       Richard Bruce Wright                 2001     HarperFlamingo Canada
# 1               Carlo D'Este                 1991           HarperPerennial
# 2           Gina Bari Kolata                 1999      Farrar Straus Giroux
# 3                    Amy Tan                 1991          Putnam Pub Group
# 4              Robert Cowley                 2000  Berkley Publishing Group
# ...                      ...                  ...                       ...
# 149565         P.J. O'Rourke                 1987              Pocket Books
# 149566          Sam Lightner                 2001            Broadway Books
# 149567         Claude Dooley                 1985           Lone Star Books
# 149568          Jeremy Lloyd                 1997                Kqed Books
# 149569                Mapsco                 1999  American Map Corporation
#
#                                                   img_url language  \
# 0       http://images.amazon.com/images/P/0002005018.0...       en
# 1       http://images.amazon.com/images/P/0060973129.0...       en
# 2       http://images.amazon.com/images/P/0374157065.0...       en
# 3       http://images.amazon.com/images/P/0399135782.0...       en
# 4       http://images.amazon.com/images/P/0425176428.0...       en
# ...                                                   ...      ...
# 149565  http://images.amazon.com/images/P/067161746X.0...       en
# 149566  http://images.amazon.com/images/P/0767907566.0...       en
# 149567  http://images.amazon.com/images/P/0884159221.0...      NaN
# 149568  http://images.amazon.com/images/P/0912333022.0...       en
# 149569  http://images.amazon.com/images/P/1569661057.0...      NaN
#
#              category                           img_path
# 0       ['Actresses']  images/0002005018.01.THUMBZZZ.jpg
# 1       ['1940-1949']  images/0060973129.01.THUMBZZZ.jpg
# 2         ['Medical']  images/0374157065.01.THUMBZZZ.jpg
# 3         ['Fiction']  images/0399135782.01.THUMBZZZ.jpg
# 4         ['History']  images/0425176428.01.THUMBZZZ.jpg
# ...               ...                                ...
# 149565      ['Humor']  images/067161746X.01.THUMBZZZ.jpg
# 149566     ['Nature']  images/0767907566.01.THUMBZZZ.jpg
# 149567            NaN  images/0884159221.01.THUMBZZZ.jpg
# 149568    ['Fiction']  images/0912333022.01.THUMBZZZ.jpg
# 149569            NaN  images/1569661057.01.THUMBZZZ.jpg
#
# [149570 rows x 9 columns]

# %% [markdown]
# ## category
# - category high로 묶어주기
# - category null값 book_title, book_author 같을 때 na 아닌 거 있으면 걔로 채워넣어주기

# %%
# 일단 category에서 대괄호 밖으로 빼기
books.loc[books[books['category'].notnull()].index, 'category'] = books[books['category'].notnull()]['category'].apply(lambda x: re.sub('[\W_]+',' ',x).strip())
# 소문자로 바꾸기
books['category'] = books['category'].str.lower()
books
# Out:
#               isbn                                         book_title  \
# 0       0002005018                                       Clara Callan
# 1       0060973129                               Decision in Normandy
# 2       0374157065  Flu: The Story of the Great Influenza Pandemic...
# 3       0399135782                             The Kitchen God's Wife
# 4       0425176428  What If?: The World's Foremost Military Histor...
# ...            ...                                                ...
# 149565  067161746X  The Bachelor Home Companion: A Practical Guide...
# 149566  0767907566  All Elevations Unknown: An Adventure in the He...
# 149567  0884159221  Why stop?: A guide to Texas historical roadsid...
# 149568  0912333022  The Are You Being Served? Stories: 'Camping In...
# 149569  1569661057  Dallas Street Map Guide and Directory, 2000 Ed...
#
#                  book_author  year_of_publication                 publisher  \
# 0       Richard Bruce Wright                 2001     HarperFlamingo Canada
# 1               Carlo D'Este                 1991           HarperPerennial
# 2           Gina Bari Kolata                 1999      Farrar Straus Giroux
# 3                    Amy Tan                 1991          Putnam Pub Group
# 4              Robert Cowley                 2000  Berkley Publishing Group
# ...                      ...                  ...                       ...
# 149565         P.J. O'Rourke                 1987              Pocket Books
# 149566          Sam Lightner                 2001            Broadway Books
# 149567         Claude Dooley                 1985           Lone Star Books
# 149568          Jeremy Lloyd                 1997                Kqed Books
# 149569                Mapsco                 1999  American Map Corporation
#
#                                                   img_url language   category  \
# 0       http://images.amazon.com/images/P/0002005018.0...       en  actresses
# 1       http://images.amazon.com/images/P/0060973129.0...       en  1940 1949
# 2       http://images.amazon.com/images/P/0374157065.0...       en    medical
# 3       http://images.amazon.com/images/P/0399135782.0...       en    fiction
# 4       http://images.amazon.com/images/P/0425176428.0...       en    history
# ...                                                   ...      ...        ...
# 149565  http://images.amazon.com/images/P/067161746X.0...       en      humor
# 149566  http://images.amazon.com/images/P/0767907566.0...       en     nature
# 149567  http://images.amazon.com/images/P/0884159221.0...      NaN        NaN
# 149568  http://images.amazon.com/images/P/0912333022.0...       en    fiction
# 149569  http://images.amazon.com/images/P/1569661057.0...      NaN        NaN
#
#                                  img_path
# 0       images/0002005018.01.THUMBZZZ.jpg
# 1       images/0060973129.01.THUMBZZZ.jpg
# 2       images/0374157065.01.THUMBZZZ.jpg
# 3       images/0399135782.01.THUMBZZZ.jpg
# 4       images/0425176428.01.THUMBZZZ.jpg
# ...                                   ...
# 149565  images/067161746X.01.THUMBZZZ.jpg
# 149566  images/0767907566.01.THUMBZZZ.jpg
# 149567  images/0884159221.01.THUMBZZZ.jpg
# 149568  images/0912333022.01.THUMBZZZ.jpg
# 149569  images/1569661057.01.THUMBZZZ.jpg
#
# [149570 rows x 9 columns]

# %%
category_df = pd.DataFrame(books['category'].value_counts()).reset_index()

# %%
category_df.columns = ['category','count']
category_df[category_df['count']>=10]
# Out:
#                       category  count
# 0                      fiction  33016
# 1             juvenile fiction   5835
# 2      biography autobiography   3326
# 3                      history   1927
# 4                     religion   1818
# ..                         ...    ...
# 253  children s poetry english     10
# 254            abused children     10
# 255                    courage     10
# 256              diary fiction     10
# 257            spanish fiction     10
#
# [258 rows x 2 columns]

# %% [markdown]
# ##### category_high

# %%
# 카테고리를 좀 더 큰 카테고리로 묶어주자
# 지금 category_high는 분류 안 된 category와 동일한 상태
books['category_high'] = books['category'].copy()

# %%
"""# category에 history가 들어가는 애들은 다 history로 묶어주기
books.loc[books[books['category'].str.contains('history',na=False)].index,'category_high'] = 'history'"""
# Out:
# "# category에 history가 들어가는 애들은 다 history로 묶어주기\nbooks.loc[books[books['category'].str.contains('history',na=False)].index,'category_high'] = 'history'"

# %%
"""books[books['category'].str.contains('history', na=False)]['category'].unique()"""
# Out:
# "books[books['category'].str.contains('history', na=False)]['category'].unique()"

# %%
"""books[books['category_high'].str.contains('history', na=False)]['category'].unique()"""
# Out:
# "books[books['category_high'].str.contains('history', na=False)]['category'].unique()"

# %%
"""categories = ['history', 'fiction', 'nonfiction','physics','adventure','fiction','nonfiction','science','science fiction',
 'jouvenile fiction', 'jouvenille nonfiction','disease','mathemat','agricult',
 'business','poetry','drama','literary','travel','motion picture','children','literature','electronic',
 'humor','computer','house','family','architect','camp','language', 'comic', 'sports', 'novel']
groupings = {'hobby' : ['crafts', 'hobbies', 'hobby', 'garden'],
             'art/media' : ['art', 'photo', 'music'],
             'house/cook' : ['cook', 'house'],
             'business' : ['economics', 'business'],
             'religion' : ['christian', 'bible', 'religion'],
             'animal' : ['animal', 'bird'],
             'social science' : ['philosophy', 'psycholog', 'social', 'sociology'],
             'criminal' : ['criminal', 'homicide'],
             'eco' : ['ecology', 'environment', 'nature']}"""
# Out:
# "categories = ['history', 'fiction', 'nonfiction','physics','adventure','fiction','nonfiction','science','science fiction',\n 'jouvenile fiction', 'jouvenille nonfiction','disease','mathemat','agricult',\n 'business','poetry','drama','literary','travel','motion picture','children','literature','electronic',\n 'humor','computer','house','family','architect','camp','language', 'comic', 'sports', 'novel']\ngroupings = {'hobby' : ['crafts', 'hobbies', 'hobby', 'garden'],\n             'art/media' : ['art', 'photo', 'music'],\n             'house/cook' : ['cook', 'house'],\n             'business' : ['economics', 'business'],\n             'religion' : ['christian', 'bible', 'religion'],\n             'animal' : ['animal', 'bird'],\n             'social science' : ['philosophy', 'psycholog', 'social', 'sociology'],\n             'criminal' : ['criminal', 'homicide'],\n             'eco' : ['ecology', 'environment', 'nature']}"

# %%
# amazon 책 분류 체계를 따름
# 포괄적인 단어는 위에 배치
## 추가된 범주: animal & Nature, literatue & poem
groupings = {'Fiction': ['fiction'], # 너무 넓으니 맨 위로 빼자
             'Literature & Poem': ['liter', 'poem', 'poetry'],
             'Science & Math': ['science', 'math', 'logy'], # science, logy 범위가 너무 넓으니 맨 위로
             'Parenting & Relationships': ['baby', 'parent', 'family', 'tionship', 'brother', 'sister'], # 좀 큼
             'Medical Books': ['medi', 'psycho'], # psy의 세분화 가능
             'Animal & Nature': ['animal', 'ecolo', 'plant', 'nature'],
             
             'Arts & Photography': ['art', 'photo'], # art는 겹치는 글자가 너무 많음
             'Biographies & Memoirs': ['biog', 'memo'],
             'Business & Money': ['busi', 'money', 'econo'],
             'Calendars': ['calen'],
             'Children\'s Books': ['child', 'baby'],
             'Christian Books & Bibles': ['christi', 'bible'], #크리스마스때매
             'Comics & Graphic Novels': ['comics', 'graphic novel'],
             'Computers & Technology': ['computer', 'techno', 'archi'],
             'Cookbooks, Food & Wine': ['cook'],
             'Crafts, Hobbies & Home': ['crafts'],
             'Education & Teaching': ['educa', 'teach'],
             'Engineering & Transportation': ['engine', 'transp'],
             'Health, Fitness & Dieting': ['health', 'fitness', 'diet'],
             'History': ['histo'],
             
             'Humor & Entertainment': ['humor', 'entertai', 'comed', 'game'],
             'Law': ['law'],
             'LGBTQ+ Books': ['lesbian', 'gay', 'bisex'],
             'Mystery, Thriller & Suspense': ['myste', 'thril', 'suspen'],
             'Politics & Social Sciences': ['politic', 'social'],
             'Reference': ['reference'],
             'Religion & Spirituality': ['religi'],
             'Romance': ['romance'],
             'Science Fiction & Fantasy': ['science fiction', 'fantasy'],
             'Self-Help': ['self'], # self 검색시 모두 자기계발 관련
             'Sports & Outdoors': ['exerc','sport','outdoor'],
             'Teen & Young Adult': ['teen', 'adol', 'juven'], #nonfiction이란 말은 청소년 관련뿐
             'Test Preparation': ['test', 'school', 'examina'],
             'Travel': ['travel'],
}

# %%
# 검색용 코드
word = 'losophy'
books[books['category'].str.contains(word, na=False)]['category'].unique()
books[books['category'].str.contains(word, na=False)]['category'].value_counts()
# Out:
# philosophy                       481
# appearance philosophy              1
# essentialism philosophy            1
# educational philosophy             1
# philosophy chinese                 1
# buddhist philosophy                1
# philosophy and religion            1
# essence philosophy                 1
# psychoanalysis and philosophy      1
# constructivism philosophy          1
# indian philosophy                  1
# irrationalism philosophy           1
# Name: category, dtype: int64

# %%
# 상위 카테고리 묶기, 기본적으로 제공된 카테고리 기반 묶기
"""for category in categories:
    books.loc[books[books['category'].str.contains(category,na=False)].index,'category_high'] = category"""
# Out:
# "for category in categories:\n    books.loc[books[books['category'].str.contains(category,na=False)].index,'category_high'] = category"

# %%
books[books['category'] == 'music']
# Out:
#               isbn                                         book_title  \
# 439     051788139X  The Harmony Illustrated Encyclopedia of Countr...
# 504     1567310877            Shout!: The Beatles in Their Generation
# 2803    0316441791  Set Your Voice Free : Foreword by Dr. Laura Sc...
# 3410    0806512318  The Worst Rock-And-Roll Records of All Time: A...
# 5043    0025473905                                 Respect for Acting
# ...            ...                                                ...
# 147513  0306807114                Up and Down With the Rolling Stones
# 147828  0312014694                           Liberace: The True Story
# 148194  0670808423  Tone Deaf and All Thumbs?: An Invitation to Mu...
# 148216  0140469583  The Penguin Guide to Compact Discs and Cassett...
# 148869  0825301815                       David Bowie: Out of the Cool
#
#             book_author  year_of_publication                     publisher  \
# 439        Alan Cackett                 1994              Random House Inc
# 504       Philip Norman                 1997                     MJF Books
# 2803         Roger Love                 1999                 Little, Brown
# 3410     Jimmy Guterman                 1991  Carol Publishing Corporation
# 5043         Uta  Hagen                 1973             John Wiley & Sons
# ...                 ...                  ...                           ...
# 147513     Tony Sanchez                 1996                 Da Capo Press
# 147828       Bob Thomas                 1988                 St Martins Pr
# 148194  Frank R. Wilson                 1986                   Penguin USA
# 148216       Ivan March                 1994                   Penguin USA
# 148869     Philip Kamin                 1983                Beaufort Books
#
#                                                   img_url language category  \
# 439     http://images.amazon.com/images/P/051788139X.0...       en    music
# 504     http://images.amazon.com/images/P/1567310877.0...       en    music
# 2803    http://images.amazon.com/images/P/0316441791.0...       en    music
# 3410    http://images.amazon.com/images/P/0806512318.0...       en    music
# 5043    http://images.amazon.com/images/P/0025473905.0...       en    music
# ...                                                   ...      ...      ...
# 147513  http://images.amazon.com/images/P/0306807114.0...       en    music
# 147828  http://images.amazon.com/images/P/0312014694.0...       en    music
# 148194  http://images.amazon.com/images/P/0670808423.0...       en    music
# 148216  http://images.amazon.com/images/P/0140469583.0...       en    music
# 148869  http://images.amazon.com/images/P/0825301815.0...       en    music
#
#                                  img_path category_high
# 439     images/051788139X.01.THUMBZZZ.jpg         music
# 504     images/1567310877.01.THUMBZZZ.jpg         music
# 2803    images/0316441791.01.THUMBZZZ.jpg         music
# 3410    images/0806512318.01.THUMBZZZ.jpg         music
# 5043    images/0025473905.01.THUMBZZZ.jpg         music
# ...                                   ...           ...
# 147513  images/0306807114.01.THUMBZZZ.jpg         music
# 147828  images/0312014694.01.THUMBZZZ.jpg         music
# 148194  images/0670808423.01.THUMBZZZ.jpg         music
# 148216  images/0140469583.01.THUMBZZZ.jpg         music
# 148869  images/0825301815.01.THUMBZZZ.jpg         music
#
# [320 rows x 10 columns]

# %%
# grouping 하기, 파편화된 카테고리를 대주제로 묶기
for new_group, small in groupings.items():
    for s in small:
        books.loc[books[books['category'].str.contains(s, na = False)].index, 'category_high'] = new_group

# %%
books[books['category_high'] == 'Science & Math']['category'].value_counts() # logy를 다 묶었는데 psychology는 빠져있는 모습
# Out:
# science                     624
# mathematics                  70
# archaeology                  10
# astrology                     9
# aromatherapy                  7
#                            ...
# environmental geology         1
# eschatology                   1
# ideology                      1
# conscience in literature      1
# climatology                   1
# Name: category, Length: 65, dtype: int64

# %%
books['category_high'].value_counts()
# Out:
# Fiction                     33672
# Teen & Young Adult           7351
# Biographies & Memoirs        3369
# History                      1994
# Religion & Spirituality      1835
#                             ...
# voyages around the world        1
# buddhists                       1
# glasnost                        1
# icarian community               1
# deafness                        1
# Name: category_high, Length: 2991, dtype: int64

# %%
# 10개 이하인 카테고리를 Unclassified로 묶고 싶은데 어떻게 하는지 모르겠음
"""books.loc(books['category_high'].value_counts() < 10, 'category_high')
"""
# Out:
# "books.loc(books['category_high'].value_counts() < 10, 'category_high')\n"

# %% [markdown]
# ##### category null 값 묶기

# %%
books['category_new'] = books['category_high'].copy()
books['category_new'] = books['category_new'].fillna('Unclassified')

# %%
books.isna().sum()
# Out:
# isbn                       0
# book_title                 0
# book_author                0
# year_of_publication        0
# publisher                  0
# img_url                    0
# language               67227
# category               68851
# img_path                   0
# category_high          68851
# category_new               0
# dtype: int64

# %%
tmp = books.groupby(['book_title', 'book_author'])['category_new'].apply(lambda x : ' / '.join(x)).to_frame()

# %%
tmp.reset_index(drop=False)['category_new'].value_counts().tail(20)
# Out:
# appaloosa horse                                           1
# adapted books                                             1
# cottages                                                  1
# Fiction / Unclassified / british                          1
# michigan                                                  1
# house home / house home / Engineering & Transportation    1
# marketing surveys                                         1
# true crime / Parenting & Relationships / true crime       1
# women journalists                                         1
# billion the number                                        1
# conversation                                              1
# Religion & Spirituality / Science & Math                  1
# death / Parenting & Relationships                         1
# Unclassified / Unclassified / authors american            1
# telemarketing                                             1
# hiding places                                             1
# subways                                                   1
# saving and investment                                     1
# problem solving                                           1
# awk langage de programmation                              1
# Name: category_new, dtype: int64

# %%
tmp = tmp.reset_index(drop=False) ; tmp
# Out:
#                                                book_title         book_author  \
# 0        A Light in the Storm: The Civil War Diary of ...         Karen Hesse
# 1        Ask Lily (Young Women of Faith: Lily Series, ...        Nancy N. Rue
# 2                                            Dark Justice        Jack Higgins
# 3        Earth Prayers From around the World: 365 Pray...   Elizabeth Roberts
# 4        Final Fantasy Anthology: Official Strategy Gu...       David Cassady
# ...                                                   ...                 ...
# 139500  Ã?Â?bernachten mit Stil. Die schÃ?Â¶nsten Coun...  Christopher Fennel
# 139501                     Ã?Â?rger mit Produkt X. Roman.          Joan Aiken
# 139502                                Ã?Â?sterlich leben.      Anselm GrÃ?Â¼n
# 139503                              Ã?Â?stlich der Berge.      David Guterson
# 139504                                  Ã?Â?thique en toc    Didier Daeninckx
#
#                  category_new
# 0          Teen & Young Adult
# 1          Teen & Young Adult
# 2                     Fiction
# 3                Unclassified
# 4       Humor & Entertainment
# ...                       ...
# 139500           Unclassified
# 139501           Unclassified
# 139502           Unclassified
# 139503           Unclassified
# 139504      Literature & Poem
#
# [139505 rows x 3 columns]

# %% [markdown]
# ## Book_title
# - 글자 깨진거 수정, 소문자처리

# %%
def text_preprocessing_func(text : str ) -> str :
    """
    깨진 문자를 변환하는 함수
    """
    text = text.replace('Ã?Â©','e') # 원래는 é인데 걍 e로 메움
    text = text.replace('Ã©', 'e')
    text = text.replace('Ã?Â?','e') # 원래는 é인데 걍 e로 메움
    text = text.lower()
    return text

# %%
books['book_title'] = books['book_title'].apply(text_preprocessing_func)

# %%
books['book_title']
# Out:
# 0                                              clara callan
# 1                                      decision in normandy
# 2         flu: the story of the great influenza pandemic...
# 3                                    the kitchen god's wife
# 4         what if?: the world's foremost military histor...
#                                 ...
# 149565    the bachelor home companion: a practical guide...
# 149566    all elevations unknown: an adventure in the he...
# 149567    why stop?: a guide to texas historical roadsid...
# 149568    the are you being served? stories: 'camping in...
# 149569    dallas street map guide and directory, 2000 ed...
# Name: book_title, Length: 149570, dtype: object

# %% [markdown]
# ## publisher
# - 기본 텍스트 전처리
# - 유명 출판사의 경우 표기 방법의 차이 및 오타로 인해같은 그룹으로 묶이지 못하는 항목들이 있으므로 이런 항목들을 수정 => 기본 EDA 코드 활용

# %%
# 기본 텍스트 전처리
books['publisher'] = books['publisher'].apply(text_preprocessing_func)

# %%
publisher_dict=(books['publisher'].value_counts()).to_dict()
publisher_count_df= pd.DataFrame(list(publisher_dict.items()),columns = ['publisher','count'])

publisher_count_df = publisher_count_df.sort_values(by=['count'], ascending = False)

modify_list = publisher_count_df[publisher_count_df['count']>1].publisher.values
for publisher in modify_list:
    try:
        number = books[books['publisher']==publisher]['isbn'].apply(lambda x: x[:4]).value_counts().index[0]
        right_publisher = books[books['isbn'].apply(lambda x: x[:4])==number]['publisher'].value_counts().index[0]
        books.loc[books[books['isbn'].apply(lambda x: x[:4])==number].index,'publisher'] = right_publisher
    except: 
        pass

# %%
books_origin['publisher'].nunique(), books['publisher'].nunique()
# Out:
# (11571, 1514)

# %% [markdown]
# ## Language -> Country
# - isbn으로 언어를 출판 국가로 바꿔줍니다

# %%
isbn_dict = {}
isbn_dict = { books['language'][idx] : [isbn[:3]] if books['language'][idx] not in isbn_dict.keys() else isbn_dict[books['language'][idx]].append(isbn[:2]) for idx, isbn in enumerate(books['isbn'])}

# %%
isbn_dict
# Out:
# {'en': ['091'],
#  nan: ['156'],
#  'de': ['349'],
#  'fr': ['225'],
#  'es': ['843'],
#  'ca': ['848'],
#  'it': ['880'],
#  'da': ['344'],
#  'nl': ['902'],
#  'pt': ['972'],
#  'ro': ['359'],
#  'no': ['820'],
#  'ms': ['186'],
#  'la': ['052'],
#  'ru': ['140'],
#  'el': ['158'],
#  'zh-CN': ['081'],
#  'th': ['014'],
#  'gl': ['848'],
#  'ja': ['477'],
#  'fa': ['964'],
#  'eo': ['084'],
#  'gd': ['084'],
#  'ga': ['185'],
#  'vi': ['080'],
#  'zh-TW': ['068'],
#  'ko': ['043']}

# %%
isbn_code = {'0' : 'english', '1' : 'english', '2': 'franch', '3' : 'german', '4' : 'japan', '5' : 'russia', '7' : 'china',
             '65' : 'brazil', '80' : 'czecho', '81' : 'india', '82' : 'norway', '83' : 'poland', '84' : 'espanol', '85' : 'brazil', '86' : 'yugoslavia', '87' : 'danish', '88' : 'italy', '89' : 'korean', '90' : 'netherlands', '91' : 'sweden',
            '92' : 'international ngo', '93' : 'inida', '94' : 'netherlands', '600' : 'iran', '601' : 'kazakhstan', '602' : 'indonesia', '603' : 'saudi arabia', '604' : 'vietnam', '605' : 'turkey',
            '606' : 'romania', '607' : 'mexico', '608' : 'north macedonia', '609' : 'lithuania', '611' : 'thailand', '612' : 'peru', '613' : 'mauritius',
            '614' : 'lebanon', '615' : 'hungary', '616' : 'thailand', '617' : 'ukraine', '618' : 'greece', '619' : 'bulgaria', '620' : 'mauritius', '621' : 'phillippines',
            '622' : 'iran', '623' : 'indonesia', '624' : 'sri lanka', '625' : 'turkey', '626' : 'taiwan', '627' : 'pakistan', '628' : 'colombia', '629' : 'malaysia', '630' : 'romania',
            '950' : 'argentina', '951' : 'finland', '952' : 'finland', '953' : 'croatia', '954' : 'bulgaria', '955' : 'sri lanka',
            '956' : 'chile', '957' : 'taiwan', '958' : 'colombia', '959' : 'cuba', '960' : 'greece' , '961' : 'slovenia', '962' : 'hong kong',
            '963' : 'hungary', '964' : 'iran', '965' : 'israel', '966' : 'urkaine', '967' : 'malaysia', '968' : 'mexico', '969' : 'pakistan', '970' : 'mexico',
            '971' : 'phillippines', '972' : 'portugal', '973' : 'romania', '974' : 'thailand', '975' : 'turkey', '976' : 'caribbean community', '977' : 'egypt', '978' : 'nigeria', 
            '979' : 'indonesia', '980' : 'venezuela', '981' : 'singapore', '982' : 'south pacific', '983' : 'malaysia', '984' : 'bangladesh', '985' : 'velarus', '986' : 'taiwan',
            '987' : 'argentina', '988' : 'hong kong', '989' : 'portugal',
            '9960':'saudi arabia', '9963' : 'cyprus', '9968' : 'costa rica', '9971' : 'singapore', '9972' : 'peru', '9974' : 'uruguay',
            '9976' : 'tanzania', '9977' : 'costa rica', '9979' : 'iceland', '9986' : 'lithuania',
            '99903' : 'mauritius', '99905' : ' bolivia', '99909' : 'malta', '99912' : 'botswana', '99920' : 'andorra', '99928' : 'georgia',
            '99935' : 'haiti', '99936' : 'bhutan', '99942' : 'armenia', '99943' : 'albania', '99974' : 'bolivia',
            '99975' : 'mongolia', '99989' : 'paraguay'}

# %%
check_list = []
books['isbn_country'] = 'na'
for idx in range(len(books)):
    isbn = books['isbn'][idx][:5]
    if isbn[0] in isbn_code.keys():
        books.at[idx, 'isbn_country'] = isbn_code[isbn[0]]
    elif isbn[:2] in isbn_code.keys():
        books.at[idx, 'isbn_country'] = isbn_code[isbn[0:2]]
    elif isbn[:3] in isbn_code.keys():
        books.at[idx, 'isbn_country'] = isbn_code[isbn[0:3]]
    elif isbn[:4] in isbn_code.keys():
        books.at[idx, 'isbn_country'] = isbn_code[isbn[:4]]
    elif isbn[:] in isbn_code.keys():
        books.at[idx, 'isbn_country'] = isbn_code[isbn[:]]
    else:
        check_list.append(isbn)

# %%
set(check_list)
# Out:
# {'99999', 'B0000', 'B0001', 'B0002'}

# %% [markdown]
# 출판사가 headline이거나 putnam pub group인 경우에 이상한 isbn을 달고 있음
# 검색결과 putnam pub group은 penguin books의 또다른 이름으로, NYC의 미국 출판사임
# headline 또한 영국의 퍼블리싱 브랜드임 -> 둘 다 english로 바꿔줌

# %%
books[books['isbn'].apply(lambda x : x[:5]).isin(check_list)].head()
# Out:
#              isbn                                         book_title  \
# 2886   B0000DAPP1  discover your genius: how to think like histor...
# 15104  B0000A2U93                                           carmilla
# 16173  B0000633PU        the story of aladdin and the wonderful lamp
# 24710  B0000DYXID            a kid's guide to how to save the planet
# 29467  B00006CRTE  devil knows you're dead, the: a matthew scudde...
#
#                    book_author  year_of_publication         publisher  \
# 2886           Michael J. Gelb                 2002  putnam pub group
# 15104  Joseph Sheridan Le Fanu                 1994  putnam pub group
# 16173            S. Lane Poole                 1994  putnam pub group
# 24710            Billy Goodman                 1994  putnam pub group
# 29467           Lawrence Block                 1994  putnam pub group
#
#                                                  img_url language category  \
# 2886   http://images.amazon.com/images/P/B0000DAPP1.0...      NaN      NaN
# 15104  http://images.amazon.com/images/P/B0000A2U93.0...      NaN      NaN
# 16173  http://images.amazon.com/images/P/B0000633PU.0...      NaN      NaN
# 24710  http://images.amazon.com/images/P/B0000DYXID.0...      NaN      NaN
# 29467  http://images.amazon.com/images/P/B00006CRTE.0...      NaN      NaN
#
#                                 img_path category_high  category_new  \
# 2886   images/B0000DAPP1.01.THUMBZZZ.jpg           NaN  Unclassified
# 15104  images/B0000A2U93.01.THUMBZZZ.jpg           NaN  Unclassified
# 16173  images/B0000633PU.01.THUMBZZZ.jpg           NaN  Unclassified
# 24710  images/B0000DYXID.01.THUMBZZZ.jpg           NaN  Unclassified
# 29467  images/B00006CRTE.01.THUMBZZZ.jpg           NaN  Unclassified
#
#       isbn_country
# 2886            na
# 15104           na
# 16173           na
# 24710           na
# 29467           na

# %%
books[books['isbn_country'] == 'na']['isbn_country'] = 'english'
# Out:
# /tmp/ipykernel_22297/587793286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   books[books['isbn_country'] == 'na']['isbn_country'] = 'english'

# %% [markdown]
# ### 다 수정하고 확인

# %%
books['isbn_country'].value_counts()
# Out:
# english         134405
# german            6706
# franch            3405
# espanol           3399
# italy              482
#                  ...
# botswana             1
# saudi arabia         1
# iceland              1
# uruguay              1
# paraguay             1
# Name: isbn_country, Length: 67, dtype: int64

# %%
# category new가 있으니 high는 지움
books = books.drop(['category_high'], axis = 1)

# %% [markdown]
# ## author
# - 기본 텍스트 전처리 (text_preprocessing_func)

# %%
books['book_author'] = books['book_author'].apply(text_preprocessing_func)

# %%
books.head()
# Out:
#          isbn                                         book_title  \
# 0  0002005018                                       clara callan
# 1  0060973129                               decision in normandy
# 2  0374157065  flu: the story of the great influenza pandemic...
# 3  0399135782                             the kitchen god's wife
# 4  0425176428  what if?: the world's foremost military histor...
#
#             book_author  year_of_publication                 publisher  \
# 0  richard bruce wright                 2001             harpercollins
# 1          carlo d'este                 1991             harpercollins
# 2      gina bari kolata                 1999      farrar straus giroux
# 3               amy tan                 1991          putnam pub group
# 4         robert cowley                 2000  berkley publishing group
#
#                                              img_url language   category  \
# 0  http://images.amazon.com/images/P/0002005018.0...       en  actresses
# 1  http://images.amazon.com/images/P/0060973129.0...       en  1940 1949
# 2  http://images.amazon.com/images/P/0374157065.0...       en    medical
# 3  http://images.amazon.com/images/P/0399135782.0...       en    fiction
# 4  http://images.amazon.com/images/P/0425176428.0...       en    history
#
#                             img_path  category_high   category_new  \
# 0  images/0002005018.01.THUMBZZZ.jpg      actresses      actresses
# 1  images/0060973129.01.THUMBZZZ.jpg      1940 1949      1940 1949
# 2  images/0374157065.01.THUMBZZZ.jpg  Medical Books  Medical Books
# 3  images/0399135782.01.THUMBZZZ.jpg        Fiction        Fiction
# 4  images/0425176428.01.THUMBZZZ.jpg        History        History
#
#   isbn_country
# 0      english
# 1      english
# 2      english
# 3      english
# 4      english

# %% [markdown]
# # 전체 다 데이터 합쳐서 확인해보려고 함

# %%
users
# Out:
#        user_id   location_state location_country
# 0            8          ontario           canada
# 1        11400          ontario           canada
# 2        67544          ontario           canada
# 3        85526  britishcolumbia           canada
# 4        96054          ontario           canada
# ...        ...              ...              ...
# 66785   278376       california              usa
# 66786   278621         delaware           canada
# 66787   278636          alabama              usa
# 66788   278659  britishcolumbia           canada
# 66789   278713        newmexico              usa
#
# [66790 rows x 3 columns]

# %%
books
# Out:
#               isbn                                         book_title  \
# 0       0002005018                                       clara callan
# 1       0060973129                               decision in normandy
# 2       0374157065  flu: the story of the great influenza pandemic...
# 3       0399135782                             the kitchen god's wife
# 4       0425176428  what if?: the world's foremost military histor...
# ...            ...                                                ...
# 149565  067161746X  the bachelor home companion: a practical guide...
# 149566  0767907566  all elevations unknown: an adventure in the he...
# 149567  0884159221  why stop?: a guide to texas historical roadsid...
# 149568  0912333022  the are you being served? stories: 'camping in...
# 149569  1569661057  dallas street map guide and directory, 2000 ed...
#
#                  book_author  year_of_publication                 publisher  \
# 0       richard bruce wright                 2001             harpercollins
# 1               carlo d'este                 1991             harpercollins
# 2           gina bari kolata                 1999      farrar straus giroux
# 3                    amy tan                 1991          putnam pub group
# 4              robert cowley                 2000  berkley publishing group
# ...                      ...                  ...                       ...
# 149565         p.j. o'rourke                 1987                    pocket
# 149566          sam lightner                 2001            broadway books
# 149567         claude dooley                 1985       bridge publications
# 149568          jeremy lloyd                 1997            pub group west
# 149569                mapsco                 1999                soho press
#
#                                                   img_url language   category  \
# 0       http://images.amazon.com/images/P/0002005018.0...       en  actresses
# 1       http://images.amazon.com/images/P/0060973129.0...       en  1940 1949
# 2       http://images.amazon.com/images/P/0374157065.0...       en    medical
# 3       http://images.amazon.com/images/P/0399135782.0...       en    fiction
# 4       http://images.amazon.com/images/P/0425176428.0...       en    history
# ...                                                   ...      ...        ...
# 149565  http://images.amazon.com/images/P/067161746X.0...       en      humor
# 149566  http://images.amazon.com/images/P/0767907566.0...       en     nature
# 149567  http://images.amazon.com/images/P/0884159221.0...      NaN        NaN
# 149568  http://images.amazon.com/images/P/0912333022.0...       en    fiction
# 149569  http://images.amazon.com/images/P/1569661057.0...      NaN        NaN
#
#                                  img_path           category_new isbn_country
# 0       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 1       images/0060973129.01.THUMBZZZ.jpg              1940 1949      english
# 2       images/0374157065.01.THUMBZZZ.jpg          Medical Books      english
# 3       images/0399135782.01.THUMBZZZ.jpg                Fiction      english
# 4       images/0425176428.01.THUMBZZZ.jpg                History      english
# ...                                   ...                    ...          ...
# 149565  images/067161746X.01.THUMBZZZ.jpg  Humor & Entertainment      english
# 149566  images/0767907566.01.THUMBZZZ.jpg        Animal & Nature      english
# 149567  images/0884159221.01.THUMBZZZ.jpg           Unclassified      english
# 149568  images/0912333022.01.THUMBZZZ.jpg                Fiction      english
# 149569  images/1569661057.01.THUMBZZZ.jpg           Unclassified      english
#
# [149570 rows x 11 columns]

# %%
user_ratings = pd.merge(left = ratings, right = users, left_on = 'user_id', right_on = 'user_id')
data = pd.merge(left = user_ratings, right = books, left_on = 'isbn', right_on = 'isbn')

# %%
len(data), len(ratings)
# Out:
# (296398, 306795)

# %%
# count 내림차순으로 보고싶어서 코드 수저

popular_book_dict = data['isbn'].value_counts().sort_values(ascending=False)[:30].to_dict()

popular_book = data[data['isbn'].isin(popular_book_dict.keys())].reset_index(drop=True)
popular_book['count'] = 0

for i in range(len(popular_book)):
    popular_book.at[i, 'count'] = popular_book_dict[popular_book['isbn'].iloc[i]]
    
popular_book = popular_book.sort_values(by='count', ascending=False)

# %%
# popular_book_list = data['isbn'].value_counts().sort_values(ascending=False)[:30].index
# popular_book = data[data['isbn'].isin(popular_book_list)]

fig, ax1 = plt.subplots(figsize=(20,6))
plt.xticks(rotation=80)
sns.lineplot(data = popular_book,x='book_title',y='rating' ,marker='o', estimator=np.median, ax=ax1)
ax2 = ax1.twinx()

sns.countplot(data=popular_book, x='book_title', alpha=0.5, ax=ax2)
plt.show()

# %% [markdown]
# - 뭐지.. wild animus에 1점 준 user들의 rating 분포를 살펴보려고 함

# %%
# wild animus에 1점 준 user id
rating_one_user_id = popular_book[popular_book['count'] == 445]['user_id']
# 걔네만 df 해서 mean값 봄
rating_one_user_df = data[data['user_id'].isin(rating_one_user_id)].groupby('user_id').mean().reset_index(drop=False)
rating_one_user_df = rating_one_user_df.sort_values(by='rating').reset_index(drop=True)

rating_one_user_df
# Out:
#      user_id     rating  year_of_publication
# 0     229635   1.000000          2004.000000
# 1      42032   1.000000          2004.000000
# 2     244923   1.000000          2004.000000
# 3     125889   1.000000          2004.000000
# 4     126851   1.000000          2004.000000
# ..       ...        ...                  ...
# 440   136747   9.538462          1998.615385
# 441    12272   9.882353          1993.529412
# 442    23021  10.000000          2004.000000
# 443   162528  10.000000          2004.000000
# 444    33875  10.000000          2004.000000
#
# [445 rows x 3 columns]

# %% [markdown]
# - 흠.. 좀 펴점이 짠 애들이 분포하고는 있으나 이걸 가지고 이상하다고 볼 수가 있나?

# %%
sns.violinplot(data = rating_one_user_df, x = 'rating')
# Out:
# <AxesSubplot:xlabel='rating'>

# %% [markdown]
# - wild aniums의 별점 분포를 따로 봐야겠음
# - 걍 진짜루.. 1점을ㅈ ㅜㄴ 애들이 많음

# %%
sns.violinplot(data[data['book_title'] == 'Wild Animus']['rating'].reset_index(drop=True))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Rating 분포

# %%
# 그냥 rating의 분포
sns.violinplot(data = data, x = 'rating')
# Out:
# <AxesSubplot:xlabel='rating'>

# %%
# user 별 rating 평균
sns.distplot(data.groupby('user_id').mean()['rating'].reset_index(drop=True))
# Out:
# /tmp/ipykernel_17913/606092147.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data.groupby('user_id').mean()['rating'].reset_index(drop=True))
# <AxesSubplot:xlabel='rating', ylabel='Density'>

# %% [markdown]
# ### Rating에 대한 correlation

# %%
def cramers_v(x, y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = ss.chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    phi2 = chi2/n
    r,k = confusion_matrix.shape
    phi2corr = max(0, phi2-((k-1)*(r-1))/(n-1))
    rcorr = r-((r-1)**2)/(n-1)
    kcorr = k-((k-1)**2)/(n-1)
    return np.sqrt(phi2corr/min((kcorr-1),(rcorr-1)))

# %%
data.columns
# Out:
# Index(['user_id', 'isbn', 'rating', 'location_state', 'location_country',
#        'book_title', 'book_author', 'year_of_publication', 'publisher',
#        'img_url', 'language', 'category', 'img_path', 'category_high',
#        'category_new'],
#       dtype='object')

# %%
cramers_v(data['location_country'], data['rating'])
# Out:
# 0.0386786815369926

# %%
cramers_v(data['book_title'], data['rating'])
# Out:
# 0.1877094847382023

# %%
cramers_v(data['book_author'], data['rating'])
# Out:
# 0.16730982914843956

# %%
cramers_v(data['publisher'], data['rating'])
# Out:
# 0.09478192453715098

# %%
cramers_v(data['language'], data['rating'])
# Out:
# 0.012086621981946854

# %%
cramers_v(data['category_high'], data['rating'])
# Out:
# 0.0384281973095257

# %%
cramers_v(data['user_id'], data['rating'])
# Out:
# 0.25400751883525396

# %%
# user의 평균 rating 개수 => 날릴까?...
np.quantile(data.groupby('user_id').count()['isbn'], 0.58)
data.groupby('user_id').count()['isbn'].mean()
# Out:
# 5.051434998977435

# %%
sum(data.groupby('user_id').count()['isbn'] <= 1)
# Out:
# 33909

# %%
ttmp = pd.merge(left = test, right = users, left_on = 'user_id', right_on = 'user_id', how = 'inner')
len(test) - len(ttmp) # 2647명이 처음 보는 user
# Out:
# 2647

# %% [markdown]
# - 처음 보는 user에 대해서는 rule based로 접근해야 한다

# %%
ttmp = pd.merge(left = test, right = books, left_on = 'isbn', right_on = 'isbn', how = 'inner')
len(test) - len(ttmp) # 처음 보는 책은 없네
# Out:
# 0

# %% [markdown]
# - 평가가 한개만 있는 애들은 다 날려볼까? => 킹석자의 주관으로 날려도 됨 영향력 없어보임

# %%
data
# Out:
#         user_id        isbn  rating   location_state location_country  \
# 0             8  0002005018       4          ontario           canada
# 1         67544  0002005018       7          ontario           canada
# 2        123629  0002005018       8          ontario           canada
# 3        200273  0002005018       8          ontario           canada
# 4        210926  0002005018       9          ontario           canada
# ...         ...         ...     ...              ...              ...
# 296393   278411  0446608831       8            texas              usa
# 296394   278621  1550390961       8         delaware           canada
# 296395   278636  0375507299       2          alabama              usa
# 296396   278659  0345330293      10  britishcolumbia           canada
# 296397   278713  0670528951       7        newmexico              usa
#
#                                           book_title            book_author  \
# 0                                       clara callan   richard bruce wright
# 1                                       clara callan   richard bruce wright
# 2                                       clara callan   richard bruce wright
# 3                                       clara callan   richard bruce wright
# 4                                       clara callan   richard bruce wright
# ...                                              ...                    ...
# 296393                        texas crime chronicles          texas monthly
# 296394  gilean douglas: writing nature, finding home  andrea pinto lebowitz
# 296395               the snow geese: a story of home        william fiennes
# 296396                               town like alice            nevil shute
# 296397                                  orson welles        barbara leaming
#
#         year_of_publication          publisher  \
# 0                      2001      harpercollins
# 1                      2001      harpercollins
# 2                      2001      harpercollins
# 3                      2001      harpercollins
# 4                      2001      harpercollins
# ...                     ...                ...
# 296393                 2000       warner books
# 296394                 1999          ecw press
# 296395                 2002  vintage books usa
# 296396                 1981   ballantine books
# 296397                 1985       viking books
#
#                                                   img_url language  \
# 0       http://images.amazon.com/images/P/0002005018.0...       en
# 1       http://images.amazon.com/images/P/0002005018.0...       en
# 2       http://images.amazon.com/images/P/0002005018.0...       en
# 3       http://images.amazon.com/images/P/0002005018.0...       en
# 4       http://images.amazon.com/images/P/0002005018.0...       en
# ...                                                   ...      ...
# 296393  http://images.amazon.com/images/P/0446608831.0...      NaN
# 296394  http://images.amazon.com/images/P/1550390961.0...       en
# 296395  http://images.amazon.com/images/P/0375507299.0...      NaN
# 296396  http://images.amazon.com/images/P/0345330293.0...      NaN
# 296397  http://images.amazon.com/images/P/0670528951.0...       en
#
#                                                category  \
# 0                                             actresses
# 1                                             actresses
# 2                                             actresses
# 3                                             actresses
# 4                                             actresses
# ...                                                 ...
# 296393                                              NaN
# 296394  authors canadian english 20th century biography
# 296395                                              NaN
# 296396                                              NaN
# 296397                          biography autobiography
#
#                                  img_path           category_new isbn_country
# 0       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 1       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 2       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 3       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 4       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# ...                                   ...                    ...          ...
# 296393  images/0446608831.01.THUMBZZZ.jpg           Unclassified      english
# 296394  images/1550390961.01.THUMBZZZ.jpg  Biographies & Memoirs      english
# 296395  images/0375507299.01.THUMBZZZ.jpg           Unclassified      english
# 296396  images/0345330293.01.THUMBZZZ.jpg           Unclassified      english
# 296397  images/0670528951.01.THUMBZZZ.jpg  Biographies & Memoirs      english
#
# [296398 rows x 15 columns]

# %%
user_count = data.groupby('user_id').count()['isbn'].to_dict()

# %%
user_count
# Out:
# {8: 7,
#  9: 1,
#  12: 1,
#  14: 2,
#  16: 1,
#  17: 2,
#  19: 1,
#  22: 1,
#  26: 2,
#  32: 1,
#  39: 2,
#  42: 1,
#  44: 1,
#  53: 2,
#  56: 2,
#  64: 1,
#  67: 1,
#  69: 1,
#  70: 1,
#  75: 1,
#  78: 1,
#  81: 1,
#  82: 1,
#  85: 1,
#  86: 1,
#  87: 1,
#  88: 1,
#  92: 2,
#  97: 1,
#  99: 7,
#  102: 1,
#  107: 1,
#  110: 1,
#  114: 6,
#  125: 1,
#  129: 1,
#  133: 1,
#  141: 1,
#  162: 1,
#  165: 2,
#  169: 1,
#  178: 1,
#  183: 3,
#  185: 1,
#  202: 1,
#  217: 1,
#  224: 1,
#  226: 1,
#  228: 2,
#  230: 1,
#  232: 3,
#  242: 17,
#  243: 17,
#  244: 6,
#  247: 1,
#  254: 45,
#  256: 2,
#  272: 2,
#  273: 1,
#  289: 2,
#  300: 5,
#  302: 1,
#  310: 1,
#  313: 1,
#  323: 1,
#  339: 1,
#  356: 1,
#  361: 2,
#  362: 1,
#  367: 1,
#  372: 1,
#  376: 2,
#  383: 4,
#  387: 4,
#  388: 12,
#  392: 9,
#  393: 2,
#  408: 4,
#  413: 2,
#  424: 4,
#  430: 1,
#  431: 1,
#  433: 1,
#  440: 3,
#  441: 3,
#  444: 3,
#  446: 8,
#  447: 1,
#  453: 1,
#  463: 1,
#  472: 3,
#  475: 1,
#  476: 3,
#  479: 1,
#  486: 2,
#  487: 5,
#  494: 1,
#  496: 1,
#  499: 1,
#  500: 2,
#  503: 10,
#  505: 8,
#  507: 27,
#  508: 2,
#  512: 1,
#  513: 1,
#  537: 1,
#  538: 1,
#  542: 1,
#  558: 1,
#  566: 4,
#  567: 4,
#  585: 1,
#  592: 1,
#  595: 6,
#  596: 2,
#  619: 4,
#  620: 1,
#  625: 8,
#  626: 2,
#  628: 1,
#  638: 45,
#  639: 1,
#  640: 2,
#  641: 1,
#  643: 35,
#  649: 1,
#  650: 1,
#  651: 19,
#  657: 2,
#  660: 1,
#  677: 1,
#  685: 2,
#  695: 4,
#  698: 1,
#  707: 3,
#  709: 17,
#  712: 1,
#  714: 2,
#  717: 1,
#  726: 2,
#  728: 1,
#  730: 1,
#  735: 9,
#  739: 1,
#  741: 14,
#  743: 1,
#  744: 2,
#  746: 4,
#  753: 9,
#  756: 1,
#  757: 1,
#  758: 2,
#  759: 1,
#  763: 2,
#  765: 1,
#  767: 1,
#  771: 1,
#  774: 1,
#  776: 5,
#  777: 2,
#  778: 1,
#  780: 1,
#  782: 1,
#  785: 1,
#  786: 1,
#  790: 1,
#  805: 20,
#  811: 1,
#  818: 1,
#  819: 2,
#  824: 1,
#  827: 2,
#  828: 1,
#  834: 5,
#  843: 3,
#  850: 13,
#  853: 4,
#  878: 1,
#  882: 31,
#  883: 1,
#  885: 2,
#  886: 1,
#  887: 1,
#  895: 1,
#  899: 5,
#  900: 10,
#  901: 9,
#  903: 1,
#  913: 1,
#  914: 4,
#  915: 1,
#  921: 1,
#  929: 19,
#  938: 1,
#  951: 1,
#  969: 1,
#  984: 2,
#  1008: 1,
#  1009: 2,
#  1010: 1,
#  1016: 1,
#  1019: 1,
#  1021: 1,
#  1022: 2,
#  1024: 1,
#  1025: 26,
#  1026: 1,
#  1031: 2,
#  1032: 2,
#  1048: 3,
#  1054: 2,
#  1060: 1,
#  1063: 6,
#  1075: 7,
#  1079: 1,
#  1082: 1,
#  1083: 5,
#  1087: 1,
#  1093: 1,
#  1095: 2,
#  1096: 1,
#  1098: 1,
#  1108: 1,
#  1111: 1,
#  1113: 4,
#  1116: 6,
#  1118: 2,
#  1123: 1,
#  1124: 1,
#  1129: 7,
#  1131: 14,
#  1133: 1,
#  1137: 1,
#  1140: 1,
#  1155: 10,
#  1161: 5,
#  1164: 1,
#  1166: 1,
#  1167: 6,
#  1169: 1,
#  1174: 1,
#  1178: 4,
#  1180: 1,
#  1184: 4,
#  1192: 2,
#  1210: 1,
#  1211: 37,
#  1214: 2,
#  1219: 2,
#  1234: 1,
#  1235: 1,
#  1242: 1,
#  1248: 17,
#  1249: 2,
#  1252: 1,
#  1254: 1,
#  1258: 1,
#  1259: 1,
#  1261: 4,
#  1262: 2,
#  1263: 1,
#  1264: 1,
#  1266: 1,
#  1267: 1,
#  1279: 2,
#  1281: 1,
#  1294: 3,
#  1296: 1,
#  1297: 4,
#  1309: 1,
#  1330: 1,
#  1343: 2,
#  1344: 1,
#  1348: 2,
#  1355: 1,
#  1360: 1,
#  1368: 3,
#  1372: 2,
#  1375: 1,
#  1376: 4,
#  1389: 1,
#  1396: 1,
#  1399: 2,
#  1403: 1,
#  1409: 5,
#  1412: 4,
#  1417: 1,
#  1424: 53,
#  1427: 1,
#  1433: 1,
#  1434: 1,
#  1435: 40,
#  1436: 3,
#  1439: 1,
#  1442: 1,
#  1448: 1,
#  1455: 1,
#  1466: 2,
#  1467: 4,
#  1473: 1,
#  1484: 1,
#  1485: 4,
#  1486: 1,
#  1489: 1,
#  1491: 1,
#  1499: 3,
#  1500: 1,
#  1511: 1,
#  1517: 2,
#  1519: 1,
#  1530: 1,
#  1535: 1,
#  1548: 9,
#  1554: 1,
#  1556: 1,
#  1558: 5,
#  1570: 1,
#  1582: 1,
#  1583: 1,
#  1585: 12,
#  1586: 1,
#  1591: 1,
#  1596: 2,
#  1597: 4,
#  1608: 2,
#  1615: 1,
#  1616: 1,
#  1617: 2,
#  1619: 1,
#  1633: 1,
#  1639: 1,
#  1652: 3,
#  1653: 1,
#  1654: 1,
#  1660: 7,
#  1674: 21,
#  1683: 1,
#  1684: 1,
#  1688: 5,
#  1696: 3,
#  1706: 5,
#  1718: 1,
#  1719: 3,
#  1721: 1,
#  1723: 1,
#  1725: 3,
#  1730: 1,
#  1733: 71,
#  1759: 1,
#  1768: 1,
#  1775: 1,
#  1782: 1,
#  1790: 6,
#  1791: 2,
#  1792: 2,
#  1797: 1,
#  1799: 1,
#  1803: 1,
#  1805: 8,
#  1807: 1,
#  1812: 4,
#  1830: 2,
#  1835: 1,
#  1838: 2,
#  1844: 1,
#  1846: 1,
#  1848: 25,
#  1850: 1,
#  1863: 2,
#  1869: 2,
#  1878: 1,
#  1881: 1,
#  1888: 1,
#  1891: 2,
#  1892: 1,
#  1898: 2,
#  1901: 1,
#  1903: 40,
#  1905: 1,
#  1915: 1,
#  1918: 1,
#  1923: 1,
#  1928: 4,
#  1933: 1,
#  1937: 1,
#  1947: 1,
#  1949: 1,
#  1951: 1,
#  1966: 1,
#  1971: 1,
#  1978: 1,
#  1989: 1,
#  1990: 3,
#  1996: 1,
#  2009: 5,
#  2010: 10,
#  2024: 21,
#  2030: 33,
#  2033: 102,
#  2036: 2,
#  2038: 1,
#  2041: 7,
#  2043: 1,
#  2045: 1,
#  2046: 2,
#  2060: 1,
#  2063: 1,
#  2070: 1,
#  2075: 1,
#  2077: 1,
#  2082: 1,
#  2084: 11,
#  2089: 1,
#  2090: 4,
#  2097: 1,
#  2103: 11,
#  2104: 1,
#  2105: 1,
#  2106: 2,
#  2108: 1,
#  2110: 75,
#  2115: 1,
#  2116: 1,
#  2119: 1,
#  2130: 1,
#  2132: 6,
#  2134: 7,
#  2135: 2,
#  2136: 3,
#  2138: 1,
#  2139: 5,
#  2141: 1,
#  2147: 1,
#  2148: 1,
#  2152: 2,
#  2155: 1,
#  2163: 1,
#  2169: 1,
#  2170: 1,
#  2178: 1,
#  2179: 21,
#  2181: 1,
#  2183: 1,
#  2189: 5,
#  2190: 1,
#  2198: 1,
#  2199: 1,
#  2203: 1,
#  2204: 1,
#  2218: 1,
#  2219: 1,
#  2222: 2,
#  2224: 1,
#  2226: 1,
#  2230: 1,
#  2238: 2,
#  2253: 1,
#  2255: 3,
#  2276: 156,
#  2281: 2,
#  2287: 4,
#  2288: 11,
#  2295: 2,
#  2296: 2,
#  2305: 1,
#  2311: 1,
#  2312: 1,
#  2313: 21,
#  2324: 1,
#  2326: 3,
#  2329: 1,
#  2333: 2,
#  2334: 1,
#  2336: 1,
#  2337: 14,
#  2339: 1,
#  2340: 1,
#  2345: 1,
#  2349: 1,
#  2350: 1,
#  2351: 1,
#  2354: 2,
#  2355: 1,
#  2357: 1,
#  2358: 17,
#  2363: 19,
#  2366: 1,
#  2368: 1,
#  2375: 4,
#  2376: 1,
#  2379: 1,
#  2385: 2,
#  2388: 1,
#  2389: 2,
#  2399: 6,
#  2404: 1,
#  2406: 5,
#  2411: 4,
#  2414: 1,
#  2415: 1,
#  2417: 1,
#  2421: 1,
#  2425: 1,
#  2437: 7,
#  2439: 6,
#  2442: 6,
#  2448: 1,
#  2453: 1,
#  2461: 2,
#  2462: 5,
#  2466: 2,
#  2470: 2,
#  2473: 1,
#  2481: 2,
#  2484: 1,
#  2485: 1,
#  2499: 1,
#  2503: 1,
#  2504: 1,
#  2506: 1,
#  2508: 1,
#  2528: 1,
#  2534: 1,
#  2545: 2,
#  2549: 1,
#  2550: 1,
#  2552: 3,
#  2559: 3,
#  2562: 1,
#  2565: 1,
#  2574: 1,
#  2579: 1,
#  2580: 2,
#  2583: 1,
#  2589: 7,
#  2590: 1,
#  2591: 1,
#  2597: 2,
#  2605: 1,
#  2611: 1,
#  2622: 3,
#  2630: 2,
#  2632: 1,
#  2634: 1,
#  2638: 1,
#  2643: 1,
#  2644: 1,
#  2651: 2,
#  2653: 1,
#  2655: 1,
#  2665: 1,
#  2670: 1,
#  2678: 2,
#  2679: 1,
#  2681: 1,
#  2683: 1,
#  2687: 1,
#  2688: 3,
#  2690: 1,
#  2700: 1,
#  2718: 1,
#  2719: 9,
#  2731: 4,
#  2738: 1,
#  2766: 72,
#  2769: 1,
#  2770: 4,
#  2776: 2,
#  2789: 2,
#  2790: 2,
#  2793: 10,
#  2799: 12,
#  2837: 1,
#  2850: 1,
#  2853: 4,
#  2854: 2,
#  2855: 4,
#  2859: 1,
#  2861: 1,
#  2863: 1,
#  2872: 1,
#  2883: 1,
#  2889: 1,
#  2891: 43,
#  2892: 1,
#  2893: 3,
#  2906: 3,
#  2907: 1,
#  2935: 3,
#  2936: 1,
#  2945: 1,
#  2946: 1,
#  2954: 11,
#  2966: 1,
#  2972: 1,
#  2977: 45,
#  2982: 1,
#  2983: 1,
#  2985: 1,
#  2995: 1,
#  2996: 5,
#  3005: 2,
#  3009: 1,
#  3017: 5,
#  3023: 2,
#  3030: 1,
#  3032: 1,
#  3048: 1,
#  3052: 1,
#  3053: 1,
#  3054: 1,
#  3060: 1,
#  3061: 1,
#  3063: 2,
#  3071: 1,
#  3079: 1,
#  3087: 1,
#  3088: 2,
#  3095: 1,
#  3099: 3,
#  3100: 1,
#  3101: 1,
#  3104: 3,
#  3106: 4,
#  3113: 1,
#  3114: 1,
#  3133: 1,
#  3142: 4,
#  3145: 11,
#  3146: 1,
#  3150: 1,
#  3154: 2,
#  3165: 2,
#  3167: 32,
#  3168: 3,
#  3172: 1,
#  3177: 1,
#  3191: 1,
#  3192: 5,
#  3193: 2,
#  3197: 1,
#  3200: 1,
#  3206: 1,
#  3209: 1,
#  3232: 1,
#  3260: 1,
#  3261: 1,
#  3282: 15,
#  3283: 1,
#  3289: 3,
#  3300: 1,
#  3305: 1,
#  3310: 1,
#  3315: 1,
#  3326: 8,
#  3328: 1,
#  3329: 10,
#  3331: 8,
#  3332: 2,
#  3344: 4,
#  3346: 26,
#  3350: 3,
#  3355: 4,
#  3357: 1,
#  3362: 3,
#  3363: 75,
#  3364: 1,
#  3368: 4,
#  3371: 28,
#  3373: 27,
#  3374: 3,
#  3393: 1,
#  3404: 1,
#  3416: 8,
#  3418: 6,
#  3427: 3,
#  3432: 1,
#  3437: 2,
#  3445: 1,
#  3460: 1,
#  3462: 7,
#  3463: 1,
#  3467: 3,
#  3471: 4,
#  3472: 3,
#  3473: 1,
#  3480: 1,
#  3481: 2,
#  3488: 1,
#  3492: 1,
#  3505: 1,
#  3507: 1,
#  3508: 1,
#  3509: 1,
#  3512: 1,
#  3514: 1,
#  3532: 1,
#  3537: 3,
#  3538: 19,
#  3541: 1,
#  3542: 3,
#  3543: 4,
#  3544: 1,
#  3546: 1,
#  3547: 1,
#  3549: 1,
#  3550: 1,
#  3556: 17,
#  3564: 1,
#  3573: 1,
#  3578: 13,
#  3580: 2,
#  3583: 2,
#  3588: 1,
#  3593: 1,
#  3594: 6,
#  3596: 2,
#  3599: 1,
#  3601: 2,
#  3604: 1,
#  3605: 2,
#  3611: 1,
#  3613: 1,
#  3619: 1,
#  3622: 1,
#  3628: 1,
#  3630: 1,
#  3632: 1,
#  3640: 11,
#  3643: 3,
#  3648: 1,
#  3651: 1,
#  3655: 3,
#  3656: 1,
#  3659: 1,
#  3660: 1,
#  3667: 1,
#  3669: 6,
#  3670: 1,
#  3674: 1,
#  3675: 16,
#  3679: 1,
#  3693: 10,
#  3709: 1,
#  3711: 1,
#  3712: 1,
#  3719: 13,
#  3728: 2,
#  3739: 1,
#  3752: 3,
#  3756: 1,
#  3757: 77,
#  3761: 2,
#  3764: 1,
#  3771: 1,
#  3775: 2,
#  3776: 1,
#  3779: 1,
#  3780: 1,
#  3782: 1,
#  3789: 1,
#  3792: 2,
#  3798: 1,
#  3799: 3,
#  3800: 1,
#  3814: 7,
#  3817: 7,
#  3827: 56,
#  3829: 1,
#  3836: 1,
#  3837: 1,
#  3839: 1,
#  3840: 17,
#  3842: 1,
#  3853: 1,
#  3862: 1,
#  3865: 1,
#  3871: 1,
#  3874: 3,
#  3875: 1,
#  3876: 1,
#  3884: 1,
#  3885: 1,
#  3893: 1,
#  3894: 1,
#  3902: 1,
#  3910: 1,
#  3917: 21,
#  3921: 1,
#  3923: 33,
#  3930: 1,
#  3931: 1,
#  3937: 1,
#  3938: 1,
#  3939: 2,
#  3940: 1,
#  3943: 1,
#  3944: 2,
#  3947: 1,
#  3948: 1,
#  3951: 1,
#  3952: 1,
#  3954: 2,
#  3959: 1,
#  3960: 1,
#  3965: 4,
#  3975: 1,
#  3977: 3,
#  3983: 5,
#  3999: 1,
#  4017: 126,
#  4035: 2,
#  4044: 1,
#  4049: 5,
#  4051: 2,
#  4053: 1,
#  4059: 2,
#  4066: 4,
#  4067: 1,
#  4069: 1,
#  4085: 1,
#  4090: 4,
#  4091: 5,
#  4092: 9,
#  4096: 1,
#  4097: 1,
#  4098: 7,
#  4107: 3,
#  4114: 4,
#  4118: 1,
#  4120: 1,
#  4122: 1,
#  4127: 1,
#  4130: 1,
#  4131: 10,
#  4134: 2,
#  4137: 1,
#  4138: 4,
#  4143: 1,
#  4144: 1,
#  4148: 1,
#  4149: 7,
#  4157: 23,
#  4164: 5,
#  4165: 1,
#  4169: 2,
#  4170: 1,
#  4179: 3,
#  4181: 1,
#  4183: 1,
#  4185: 1,
#  4187: 1,
#  4188: 1,
#  4191: 1,
#  4194: 1,
#  4195: 1,
#  4196: 1,
#  4197: 16,
#  4198: 1,
#  4203: 1,
#  4207: 1,
#  4216: 3,
#  4223: 7,
#  4225: 3,
#  4226: 1,
#  4228: 4,
#  4246: 1,
#  4248: 1,
#  4255: 1,
#  4258: 1,
#  4260: 3,
#  4271: 1,
#  4273: 1,
#  4285: 2,
#  4286: 1,
#  4292: 5,
#  4303: 1,
#  4309: 2,
#  4333: 1,
#  4334: 17,
#  4339: 1,
#  4343: 1,
#  4358: 1,
#  4363: 2,
#  4365: 6,
#  4366: 1,
#  4370: 2,
#  4375: 1,
#  4385: 169,
#  4386: 1,
#  4401: 6,
#  4418: 1,
#  4419: 1,
#  4420: 4,
#  4426: 1,
#  4428: 1,
#  4431: 1,
#  4432: 1,
#  4433: 4,
#  4435: 1,
#  4437: 1,
#  4438: 1,
#  4443: 1,
#  4444: 1,
#  4483: 4,
#  4495: 1,
#  4497: 1,
#  4501: 1,
#  4514: 1,
#  4516: 2,
#  4517: 1,
#  4518: 1,
#  4521: 1,
#  4539: 1,
#  4541: 3,
#  4547: 3,
#  4551: 1,
#  4556: 1,
#  4570: 5,
#  4571: 4,
#  4573: 1,
#  4579: 1,
#  4590: 2,
#  4600: 12,
#  4622: 14,
#  4702: 1,
#  4705: 3,
#  4710: 1,
#  4714: 1,
#  4720: 1,
#  4732: 1,
#  4747: 1,
#  4753: 1,
#  4766: 1,
#  4768: 1,
#  4769: 5,
#  4776: 1,
#  4781: 1,
#  4784: 1,
#  4785: 23,
#  4795: 8,
#  4799: 1,
#  4802: 6,
#  4806: 1,
#  4809: 5,
#  4816: 5,
#  4820: 1,
#  4821: 3,
#  4823: 1,
#  4838: 4,
#  4844: 1,
#  4845: 1,
#  4849: 1,
#  4852: 1,
#  4864: 2,
#  4870: 1,
#  4878: 1,
#  4881: 1,
#  4886: 1,
#  4896: 8,
#  4914: 1,
#  4937: 2,
#  4938: 18,
#  4942: 1,
#  4970: 1,
#  4972: 1,
#  4973: 1,
#  4974: 2,
#  4980: 1,
#  4994: 1,
#  4995: 1,
#  4998: 1,
#  4999: 2,
#  5003: 1,
#  5007: 1,
#  5012: 1,
#  5018: 1,
#  5021: 2,
#  5022: 1,
#  5025: 1,
#  5030: 1,
#  5034: 1,
#  5037: 12,
#  5040: 1,
#  5048: 4,
#  5049: 1,
#  5055: 2,
#  5062: 1,
#  5073: 1,
#  5079: 1,
#  5100: 2,
#  5101: 1,
#  5102: 1,
#  5120: 1,
#  5126: 2,
#  5127: 6,
#  5146: 1,
#  5151: 1,
#  5153: 2,
#  ...}

# %%
for i in range(len(data)):
    data.at[i, 'count'] = user_count[data['user_id'][i]]

# %%
data
# Out:
#         user_id        isbn  rating   location_state location_country  \
# 0             8  0002005018       4          ontario           canada
# 1         67544  0002005018       7          ontario           canada
# 2        123629  0002005018       8          ontario           canada
# 3        200273  0002005018       8          ontario           canada
# 4        210926  0002005018       9          ontario           canada
# ...         ...         ...     ...              ...              ...
# 296393   278411  0446608831       8            texas              usa
# 296394   278621  1550390961       8         delaware           canada
# 296395   278636  0375507299       2          alabama              usa
# 296396   278659  0345330293      10  britishcolumbia           canada
# 296397   278713  0670528951       7        newmexico              usa
#
#                                           book_title            book_author  \
# 0                                       clara callan   richard bruce wright
# 1                                       clara callan   richard bruce wright
# 2                                       clara callan   richard bruce wright
# 3                                       clara callan   richard bruce wright
# 4                                       clara callan   richard bruce wright
# ...                                              ...                    ...
# 296393                        texas crime chronicles          texas monthly
# 296394  gilean douglas: writing nature, finding home  andrea pinto lebowitz
# 296395               the snow geese: a story of home        william fiennes
# 296396                               town like alice            nevil shute
# 296397                                  orson welles        barbara leaming
#
#         year_of_publication          publisher  \
# 0                      2001      harpercollins
# 1                      2001      harpercollins
# 2                      2001      harpercollins
# 3                      2001      harpercollins
# 4                      2001      harpercollins
# ...                     ...                ...
# 296393                 2000       warner books
# 296394                 1999          ecw press
# 296395                 2002  vintage books usa
# 296396                 1981   ballantine books
# 296397                 1985       viking books
#
#                                                   img_url language  \
# 0       http://images.amazon.com/images/P/0002005018.0...       en
# 1       http://images.amazon.com/images/P/0002005018.0...       en
# 2       http://images.amazon.com/images/P/0002005018.0...       en
# 3       http://images.amazon.com/images/P/0002005018.0...       en
# 4       http://images.amazon.com/images/P/0002005018.0...       en
# ...                                                   ...      ...
# 296393  http://images.amazon.com/images/P/0446608831.0...      NaN
# 296394  http://images.amazon.com/images/P/1550390961.0...       en
# 296395  http://images.amazon.com/images/P/0375507299.0...      NaN
# 296396  http://images.amazon.com/images/P/0345330293.0...      NaN
# 296397  http://images.amazon.com/images/P/0670528951.0...       en
#
#                                                category  \
# 0                                             actresses
# 1                                             actresses
# 2                                             actresses
# 3                                             actresses
# 4                                             actresses
# ...                                                 ...
# 296393                                              NaN
# 296394  authors canadian english 20th century biography
# 296395                                              NaN
# 296396                                              NaN
# 296397                          biography autobiography
#
#                                  img_path           category_new isbn_country  \
# 0       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 1       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 2       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 3       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# 4       images/0002005018.01.THUMBZZZ.jpg              actresses      english
# ...                                   ...                    ...          ...
# 296393  images/0446608831.01.THUMBZZZ.jpg           Unclassified      english
# 296394  images/1550390961.01.THUMBZZZ.jpg  Biographies & Memoirs      english
# 296395  images/0375507299.01.THUMBZZZ.jpg           Unclassified      english
# 296396  images/0345330293.01.THUMBZZZ.jpg           Unclassified      english
# 296397  images/0670528951.01.THUMBZZZ.jpg  Biographies & Memoirs      english
#
#         count
# 0         7.0
# 1         7.0
# 2         1.0
# 3         1.0
# 4         5.0
# ...       ...
# 296393    1.0
# 296394    1.0
# 296395    1.0
# 296396    1.0
# 296397    1.0
#
# [296398 rows x 16 columns]

# %%
len(data) - len(data[data['count']>1])
# Out:
# 33909

# %%
data = data[data['count']>1].reset_index(drop=True)

# %%
ttmp = pd.merge(left = test, right = books, left_on = 'isbn', right_on = 'isbn', how = 'inner')
len(test) - len(ttmp) # 처음 보는 책은 없네
# Out:
# 0

# %%
user_count_2 = ratings.groupby('user_id').count()['isbn'].to_dict()
ratings_origin = ratings.copy()
for i in range(len(ratings)):
    ratings.at[i, 'count'] = user_count_2[ratings['user_id'][i]]
ratings = ratings[ratings['count']>1].reset_index(drop=True)

# %%
len(ratings_origin)
# Out:
# 306795

# %%
ratings
# Out:
#         user_id        isbn  rating  count
# 0             8  0002005018       4    7.0
# 1         67544  0002005018       7    7.0
# 2        210926  0002005018       9    5.0
# 3        219008  0002005018       7   26.0
# 4        263325  0002005018       5   40.0
# ...         ...         ...     ...    ...
# 272173   278843  0743525493       7   13.0
# 272174   278851  067161746X       6   12.0
# 272175   278851  0884159221       7   12.0
# 272176   278851  0912333022       7   12.0
# 272177   278851  1569661057      10   12.0
#
# [272178 rows x 4 columns]

# %%
len(ratings)
# Out:
# 272178

# %%
r
